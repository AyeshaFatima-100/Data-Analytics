# %% [markdown]
# #### Question 1
#
# ##### Calculate and write the output of the following expression:
# **30 + 4 × 3 − 6**

# %%
4 * 3  #Multiplication
# Out:
# 12

# %% [raw]
# step 1 answer + 30

# %%
12 + 30
# Out:
# 42

# %% [raw]
# Now the equation is 42-6

# %%
42 - 6
# Out:
# 36

# %% [markdown]
# #### Question 2
#
# ##### Calculate and write the output of the following expression:
# **100 ÷ 4 + 7 − 5**

# %%
100 / 4  #Division
# Out:
# 25.0

# %% [raw]
# step 1 answer + 7

# %%
25.0 + 7
# Out:
# 32.0

# %% [raw]
# Now the equation is 32.0-5

# %%
32.0 - 5
# Out:
# 27.0

# %% [markdown]
# #### Question 3
#
# ##### Create a variable containing the string value "100". Convert it into an integer and display its data type before and after conversion.

# %%
Century = "100"

# %%
type(Century)
# Out:
# str

# %% [raw]
# After Typecasting

# %%
Century = int(Century)

# %%
type(Century)
# Out:
# int

# %% [markdown]
# #### Question 4
#
# ##### Create the following list and display:
# ##### cities = ["Karachi", "Lahore", "Islamabad", "Peshawar", "Quetta"]
# ##### Second city
# ##### Fourth city

# %% [raw]
# Creating the List

# %%
["Karachi", "Lahore", "Islamabad", "Peshawar", "Quetta"]
# Out:
# ['Karachi', 'Lahore', 'Islamabad', 'Peshawar', 'Quetta']

# %% [raw]
# Assigning a variable to it

# %%
cities = ["Karachi", "Lahore", "Islamabad", "Peshawar", "Quetta"]

# %% [raw]
# Indexing

# %%
cities[1]
# Out:
# 'Lahore'

# %%
cities[-2]
# Out:
# 'Peshawar'

# %% [markdown]
# #### Question 5
# ##### Create the following nested list and display:
# ##### students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]
# ##### Ali
# ##### Ayesha

# %% [raw]
# first creating all lists separately

# %%
["Ali", 20]
# Out:
# ['Ali', 20]

# %%
["Ayesha", 22]
# Out:
# ['Ayesha', 22]

# %%
["Ahmed", 21]
# Out:
# ['Ahmed', 21]

# %% [raw]
# Creating the Nested List & Assigning it a viable

# %%
students = ["Ali", 20],["Ayesha", 22],["Ahmed", 21]

# %% [raw]
# indexing

# %%
students[0][0]
# Out:
# 'Ali'

# %%
students[1][0]
# Out:
# 'Ayesha'

# %% [markdown]
# #### Question 6
# ##### Given list:
# ##### numbers = [10, 20, 30, 40, 50, 60, 70]
# ##### Display:
# ##### First 3 elements
# ##### Last 3 elements

# %% [raw]
# making list and assigning it a variable

# %%
numbers = [10,20,30,40,50,60,70]

# %% [raw]
# indexing

# %%
numbers[0:3]
# Out:
# [10, 20, 30]

# %%
numbers[-3:]
# Out:
# [50, 60, 70]

# %% [markdown]
# #### Question 7
# ##### Given nested list::
# ##### students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]
# ##### Display:
# ##### Name of first student
# ##### Age of second student

# %%
students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]

# %% [raw]
# indexing

# %%
students[0][0]
# Out:
# 'Ali'

# %%
students[1][1]
# Out:
# 22

# %% [markdown]
# #### Question 8
# ##### Create a list of 5 fruits and display:
# ##### First fruit
# ##### Last fruit

# %%
fruits = ["Lychee","mango","chiku","cherry","grapes"]

# %%
fruits[0]
# Out:
# 'Lychee'

# %%
fruits[4]
# Out:
# 'grapes'

# %% [markdown]
# #### Question 9
# ##### Create the following list and display:
# ##### colors = ["Red", "Blue", "Green", "Yellow", "Black"]
# ##### First color
# ##### Last color
# ##### using negative indexing

# %%
colors = ["Red", "Blue", "Green", "Yellow", "Black"]

# %%
colors[-5]
# Out:
# 'Red'

# %%
colors[-1]
# Out:
# 'Black'

# %% [markdown]
# #### Question 10
# ##### Given nested list:
# ##### marks = [["Math", 90], ["Physics", 85], ["English", 88]]
# ##### Display:
# ##### Subject of second student
# ##### Marks of third student

# %%
marks = [["Math", 90], ["Physics", 85], ["English", 88]]

# %%
marks[1][0]
# Out:
# 'Physics'

# %%
marks[2][1]
# Out:
# 88
