# %% [markdown]
# Question 1: Age Group Classification
#
# Write a Python program that takes the age of a person as input and classifies them into one of the following age groups:
#
# "Child" if the age is between 0 and 12 (inclusive).
#
# "Teenager" if the age is between 13 and 19 (inclusive).
#
# "Adult" if the age is between 20 and 64 (inclusive).
#
# "Senior" if the age is 65 or older.

# %%
Age = int(input("enter you age here"))

if Age >= 0 and Age <= 12:
    print("Child")
elif Age >= 13 and Age <= 19:
    print("Teenager")
elif Age >= 20 and Age <= 64:
    print("Adult")
elif Age >= 65:
    print("Senior Citizen")
# Out:
# enter you age here27
# Adult

# %%
Age = int(input("enter you age here"))

if Age >= 0 and Age <= 12:
    print("Child")
elif Age >= 13 and Age <= 19:
    print("Teenager")
elif Age >= 20 and Age <= 64:
    print("Adult")
elif Age >= 65:
    print("Senior Citizen")
# Out:
# enter you age here7
# Child

# %%
Age = int(input("enter you age here"))

if Age >= 0 and Age <= 12:
    print("Child")
elif Age >= 13 and Age <= 19:
    print("Teenager")
elif Age >= 20 and Age <= 64:
    print("Adult")
elif Age >= 65:
    print("Senior Citizen")
# Out:
# enter you age here17
# Teenager

# %%
Age = int(input("enter you age here"))

if Age >= 0 and Age <= 12:
    print("Child")
elif Age >= 13 and Age <= 19:
    print("Teenager")
elif Age >= 20 and Age <= 64:
    print("Adult")
elif Age >= 65:
    print("Senior Citizen")
# Out:
# enter you age here67
# Senior Citizen

# %% [markdown]
# Q2. Write a Python program that takes three numbers as input and determines the largest among them. Also, check if any or all of the numbers are equal."

# %%
num1 = int(input("enter your first number here"))
num2 = int(input("enter your second number here"))
num3 = int(input("enter your third number here"))

if num1 >= num2 and num1 >= num3:
    print("num1 is the largest")
elif num2 >= num1 and num2 >= num3:
    print("num2 is the largest")
else:
    print("num3 is the largest")

if num1 == num2 == num3:
    print("all numbers are equal")
elif num1 == num2 or num1 == num3 or num2 == num3:
    print("two numers are equal")
else:
    print("all numbers are unequal")
# Out:
# enter your first number here10
# enter your second number here20
# enter your third number here30
# num3 is the largest
# all numbers are unequal

# %%
num1 = int(input("enter your first number here"))
num2 = int(input("enter your second number here"))
num3 = int(input("enter your third number here"))

if num1 >= num2 and num1 >= num3:
    print("num1 is the largest")
elif num2 >= num1 and num2 >= num3:
    print("num2 is the largest")
else:
    print("num3 is the largest")

if num1 == num2 == num3:
    print("all numbers are equal")
elif num1 == num2 or num1 == num3 or num2 == num3:
    print("two numers are equal")
else:
    print("all numbers are unequal")
# Out:
# enter your first number here50
# enter your second number here50
# enter your third number here20
# num1 is the largest
# two numers are equal

# %% [markdown]
# Q3. Take an integer input from the user and check whether the entered value exists in the tuple my_tuple = (5, 10, 15, 20, 25). Print an appropriate message based on the result.

# %%
my_tuple = (5, 10, 15, 20, 25)

# %%
value = int(input("enter your number here"))

if value in my_tuple:
    print("match found")
else:
    print("Access denied")
# Out:
# enter your number here20
# match found

# %%
value = int(input("enter your number here"))

if value in my_tuple:
    print("match found")
else:
    print("Access denied")
# Out:
# enter your number here90
# Access denied

# %% [markdown]
# Q4. Write a Python program to store and display the details of a book.
#
# The program should ask the user to input the following information:
#
# Title of the book
#
# Author’s name
#
# Year of publication
#
# Price of the booK
#
# Store the entered details in a tuple.
#
# Finally, display the book details in a proper format as shown below:
#
# Expected Output:
#
# Title: Harry Potter
#
# Author: JK Rowlings
#
# Year of Publication: 2000
#
# Price: $180.0

# %%
title = input("enter your book name")
author = input("enter author's name")
year = int(input("enter year of publication"))
price = float(input("enter the price of book"))

book = (title, author, year, price)

print("title", book[0])
print("author", book[1])
print("year", book[2])
print("price", book[3])
# Out:
# enter your book nameHarry potter
# enter author's nameJK Rowling
# enter year of publication2000
# enter the price of book180.0
# title Harry potter
# author JK Rowling
# year 2000
# price 180.0

# %%
book
# Out:
# ('Harry potter', 'JK Rowling', 2000, 180.0)

# %%
title = input("enter your book name")
author = input("enter author's name")
year = int(input("enter year of publication"))
price = float(input("enter the price of book"))

book = (title, author, year, price)

print("title", book[0])
print("author", book[1])
print("year", book[2])
print("price", book[3])
# Out:
# enter your book nameVerity
# enter author's nameColeen Hoover
# enter year of publication2018
# enter the price of book200.0
# title Verity
# author Coleen Hoover
# year 2018
# price 200.0

# %%
book
# Out:
# ('Verity', 'Coleen Hoover', 2018, 200.0)

# %% [markdown]
# Q5. Write a program to check if a user’s chosen subject is available in the list of offered subjects.
#
# Instructions:
#
# Given a list of subjects, ask the user to input a subject.
#
# Display whether the subject is available or not.
#
# Expected Output:
#
# Enter the subject you are interested in:  art
#
# art is available.

# %%
available_subjects = ("science, arts, commerce, humanities")

# %%
subject = input("enter your desired subject here")

if subject in available_subjects:
    print("Available")
else:
    print("not available")
# Out:
# enter your desired subject herecommerce
# Available

# %%
subject = input("enter your desired subject here")

if subject in available_subjects:
    print("Available")
else:
    print("not available")
# Out:
# enter your desired subject herecomputer science
# not available

# %% [markdown]
# Q6. Write a Python program that asks the user to enter a number.
#
# If the number is greater than 0, print "Positive".
#
# If the number is less than 0, print "Negative".
#
# If the number is exactly 0, print "Zero".
#
# Expected Output:
#
# Enter a number:  2
#
# The number is Positive
#
# ---
#
# Enter a number:  0
#
# The number is Zero
#
# ---
#
# Enter a number:  -1
#
# The number is Negative

# %%
your_number = int(input("enter your number here"))

if your_number > 0:
    print("positive")
elif your_number < 0:
    print("negative")
else:
    print("zero")
# Out:
# enter your number here20
# positive

# %%
your_number = int(input("enter your number here"))

if your_number > 0:
    print("positive")
elif your_number < 0:
    print("negative")
else:
    print("zero")
# Out:
# enter your number here-40
# negative

# %%
your_number = int(input("enter your number here"))

if your_number > 0:
    print("positive")
elif your_number < 0:
    print("negative")
else:
    print("zero")
# Out:
# enter your number here0
# zero

# %% [markdown]
# Q7. Write a Python program that simulates a simple login system.
#
# The correct username is 'admin' and the correct password is 'admin@123'
#
# The program should take username and password as input from the user.
#
# It should check the input and display messages according to the following conditions:
#
# - If both username and password are correct → print "Login Successful".
#
# - If username is wrong but password is correct → print "Invalid Username".
#
# - If username is correct but password is wrong → print "Invalid Password".
#
# - If both username and password are wrong → print "Invalid Username and Password".

# %%
user_name = ("admin")
password = ("admin@123")

# %%
user_name = input("enter your user name here")
password = input("enter your password here")

if user_name == "admin" and password == "admin@123":
    print("login successful")
elif user_name != "admin" and password == "admin@123":
    print("Invalid username")
elif user_name == "admin" and password != "admin@123":
    print("invalid password")
elif user_name != "admin" and password != "admin@123":
    print("invalid username and password")
# Out:
# enter your user name hereadmin
# enter your password hereadmin@123
# login successful

# %%
user_name = input("enter your user name here")
password = input("enter your password here")

if user_name == "admin" and password == "admin@123":
    print("login successful")
elif user_name != "admin" and password == "admin@123":
    print("Invalid username")
elif user_name == "admin" and password != "admin@123":
    print("invalid password")
elif user_name != "admin" and password != "admin@123":
    print("invalid username and password")
# Out:
# enter your user name hereadmin
# enter your password hereadmin@124
# invalid password

# %%
user_name = input("enter your user name here")
password = input("enter your password here")

if user_name == "admin" and password == "admin@123":
    print("login successful")
elif user_name != "admin" and password == "admin@123":
    print("Invalid username")
elif user_name == "admin" and password != "admin@123":
    print("invalid password")
elif user_name != "admin" and password != "admin@123":
    print("invalid username and password")
# Out:
# enter your user name hereADMIN
# enter your password hereadmin@123
# Invalid username

# %%
user_name = input("enter your user name here")
password = input("enter your password here")

if user_name == "admin" and password == "admin@123":
    print("login successful")
elif user_name != "admin" and password == "admin@123":
    print("Invalid username")
elif user_name == "admin" and password != "admin@123":
    print("invalid password")
elif user_name != "admin" and password != "admin@123":
    print("invalid username and password")
# Out:
# enter your user name hereADMIN
# enter your password hereADMIN@123
# invalid username and password

# %% [markdown]
# Q8. Write program to check a person’s eligibility for a loan based on age, credit score, and income. This time, the eligibility criteria will be:
#
# The person must be 18 years or older. The person must have a credit score of 650 or higher. The person must have an annual income of at least 30000 dollars If the person has a credit score of 700 or higher, they may still be eligible with an income of 25000 dollars or more.
#
# Expected Output:
#
# Enter your age:  22
#
# Enter your credit score:  888
#
# Enter your annual income: $ 800000
#
# You are eligible for the loan!
#
# ---
#
# Enter your age:  15
#
# Enter your credit score:  800
#
# Enter your annual income: $ 900000
#
# You are not eligible for the loan due to age.
#
# ---
#
# Enter your age:  35
#
# Enter your credit score:  99
#
# Enter your annual income: $ 900000
#
# You are not eligible for the loan due to low credit score.

# %%
age = int(input("Enter your age: "))
credit_score = int(input("Enter your credit score: "))
income = float(input("Enter your annual income: $ "))

if age < 18:
    print("You are not eligible for the loan due to age.")

elif credit_score < 650:
    print("You are not eligible for the loan due to low credit score.")

elif credit_score >= 700 and income >= 25000:
    print("You are eligible for the loan")

elif credit_score >= 650 and income >= 30000:
    print("You are eligible for the loan")

else:
    print("You are not eligible for the loan.")
# Out:
# Enter your age: 20
# Enter your credit score: 900
# Enter your annual income: $ 40000
# You are eligible for the loan

# %%
age = int(input("Enter your age: "))
credit_score = int(input("Enter your credit score: "))
income = float(input("Enter your annual income: $ "))

if age < 18:
    print("You are not eligible for the loan due to age.")

elif credit_score < 650:
    print("You are not eligible for the loan due to low credit score.")

elif credit_score >= 700 and income >= 25000:
    print("You are eligible for the loan")

elif credit_score >= 650 and income >= 30000:
    print("You are eligible for the loan")

else:
    print("You are not eligible for the loan.")
# Out:
# Enter your age: 15
# Enter your credit score: 650
# Enter your annual income: $ 30000
# You are not eligible for the loan due to age.

# %%
age = int(input("Enter your age: "))
credit_score = int(input("Enter your credit score: "))
income = float(input("Enter your annual income: $ "))

if age < 18:
    print("You are not eligible for the loan due to age.")

elif credit_score < 650:
    print("You are not eligible for the loan due to low credit score.")

elif credit_score >= 700 and income >= 25000:
    print("You are eligible for the loan")

elif credit_score >= 650 and income >= 30000:
    print("You are eligible for the loan")

else:
    print("You are not eligible for the loan.")
# Out:
# Enter your age: 25
# Enter your credit score: 400
# Enter your annual income: $ 30000
# You are not eligible for the loan due to low credit score.

# %% [markdown]
# Q9. Write a Python program to check whether the entered letter is a vowel, a consonant, or invalid input.
#
# The program should take a single character as input. If the character is a vowel (a, e, i, o, u in both upper and lower case), it will print "Vowel". If it is an alphabet but not a vowel, it will print "Consonant". Otherwise, it will print "Please enter valid alphabet".
#
# Expected Output:
#
# Enter a single letter:  a
#
# a is a Vowel
#
# ---
#
# Enter a single letter:  E
#
# E is a Vowel
#
# ---
#
# Enter a single letter:  z
#
# z is a Consonant
#
# ---
#
# Enter a single letter:  7
#
# Please enter valid alphabet

# %%
your_letter = input("enter your letter here: ").lower()

if len(your_letter) == 1 and your_letter.isalpha():
    
    if your_letter in ('a', 'e', 'i', 'o', 'u'):
        print(your_letter, "is a vowel")
    else:
        print(your_letter, "is a consonant")

else:
    print("Please enter valid alphabet")
# Out:
# enter your letter here: E
# e is a vowel

# %%
your_letter = input("enter your letter here: ").lower()

if len(your_letter) == 1 and your_letter.isalpha():
    
    if your_letter in ('a', 'e', 'i', 'o', 'u'):
        print(your_letter, "is a vowel")
    else:
        print(your_letter, "is a consonant")

else:
    print("Please enter valid alphabet")
# Out:
# enter your letter here: B
# b is a consonant

# %%
your_letter = input("enter your letter here: ").lower()

if len(your_letter) == 1 and your_letter.isalpha():
    
    if your_letter in ('a', 'e', 'i', 'o', 'u'):
        print(your_letter, "is a vowel")
    else:
        print(your_letter, "is a consonant")

else:
    print("Please enter valid alphabet")
# Out:
# enter your letter here: 9
# Please enter valid alphabet
